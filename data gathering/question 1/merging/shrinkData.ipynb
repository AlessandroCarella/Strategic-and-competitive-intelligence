# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data from CSV
data = pd.read_csv("question1reddit_twitter_counts_normalized.csv")

# %%
data.columns
# Out:
# Index(['company', 'redditCount', 'twitterCount'], dtype='object')

# %%
sorted_df = data.sort_values(by='redditCount', ascending=False)

# %%
# Select the first 20 samples
top_20 = sorted_df.head(20)

# %%
top_20
# Out:
#       company  redditCount  twitterCount
# 0      Google          242           398
# 1      OpenAI          124           259
# 2      GitHub          114            21
# 3   Microsoft          107           127
# 4      Amazon           55            20
# 5       Unity           32             1
# 6     Discord           29             3
# 7         IBM           29             2
# 8         AMD           25             0
# 9       Apple           20            20
# 10      Udemy           19             2
# 11    Twitter           15            40
# 12       Uber           12             1
# 13      Adobe           12             6
# 14    Spotify           12            11
# 15        MIT           12             1
# 16       Meta           12             9
# 17        SAP           10             0
# 18     Gemini           10             0
# 20   LinkedIn            8            15

# %%
top_20.to_csv("question1reddit_twitter_counts_normalized_cut20.csv", index=False)
