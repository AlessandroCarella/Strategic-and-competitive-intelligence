# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data from CSV
data = pd.read_csv("question1reddit_twitter_counts_normalized.csv")

# %%
data.columns
# Out:
# Index(['company', 'redditCount', 'twitterCount'], dtype='object')

# %%
sorted_df = data.sort_values(by='twitterCount', ascending=False)

# %%
# Select the first 20 samples
top_20 = sorted_df.head(20)

# %%
top_20
# Out:
#       company  redditCount  twitterCount
# 0      Google          242           398
# 1      OpenAI          124           259
# 3   Microsoft          107           127
# 11    Twitter           15            40
# 2      GitHub          114            21
# 4      Amazon           55            20
# 9       Apple           20            20
# 20   LinkedIn            8            15
# 14    Spotify           12            11
# 16       Meta           12             9
# 25    Netflix            5             9
# 43    Quizlet            1             6
# 21     Reddit            6             6
# 13      Adobe           12             6
# 31      Slack            3             4
# 45      Opera            1             3
# 6     Discord           29             3
# 29   DeepMind            3             3
# 10      Udemy           19             2
# 27      Yahoo            5             2

# %%
top_20.to_csv("question1reddit_twitter_counts_normalized_cut20.csv", index=False)
