# %% [markdown]
# question: How are discussions about coding influenced by trends in remote work, digital nomadism, and gig economy employment, from the point of views of coding professionals?

# %% [markdown]
# keywords to look for:
# 1. freelance
# 2. freelancing
# 3. remote
# 4. digital nomadism
# 5. gig economy

# %% [markdown]
# then we prompted gpt to get a better list
#
# we used the prompt
#
# give me 20 words each stricly related to the 5 keywords I'm giving you here
# 1. freelance
# 2. freelancing
# 3. remote
# 4. digital nomadism
# 5. gig economy

# %% [markdown]
# we than selected by hands the terms to remove redundancy and useless words

# %%
import pandas as pd
import os
from os import path
import json
import pickle

# %%
df = pd.read_csv(path.join("..", "..", "ChatGPT_Tweets_Dataset_Full.csv"))

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'tweet_id', 'original_text', 'sentiment', 'tasks',
#        'users', 'technologies', 'organizations', 'job_competencies',
#        'job_profiles', 'nouns', 'verbs', 'adjectives', 'subjects', 'objects',
#        'predicates', 'topic'],
#       dtype='object')
