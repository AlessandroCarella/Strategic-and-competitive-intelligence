# %% [markdown]
# questions:
#
# 1/2. which programming languages where used before and after chat gpt? (for the after we can answer via the dataset, for the before we can look on the internet for statistics)
#
# 3. which sentiments are the most frequent when talking about coding and generative ai?
#
# 4. How do Twitter conversations about competitive intelligence tools and software solutions compare in terms of user satisfaction, functionality, and ease of integration?
#
# 5. What role do open-source intelligence (OSINT) techniques and online data sources play in augmenting traditional competitive intelligence methodologies, as discussed in tweets from cybersecurity experts or OSINT practitioners?
#
# 6. What innovative approaches or methodologies are emerging in the field of coding, as discussed in tweets from academic researchers or innovation labs?
#
# 7. How are discussions about coding influenced by trends in remote work, digital nomadism, and gig economy employment, as observed in tweets from coding professionals?
#
# 8. What organizations are mentioned most often in tweets about coding (other than openai) (to understand which will grow/fail because of generative ai)?
#
# 9. Are there any specific job profiles that receive predominantly positive sentiment in tweets about coding (to understand which jobs are better after generative ai)?
#
# 10. What are the predominant subjects discussed when specific job profiles are mentioned in tweets about coding?
#
# 11. What are the ethical implications of using AI-driven competitive intelligence tools to gather and analyze data from competitor websites and social media profiles, as debated in online forums or academic papers? (answerable via papers)
#
# 12. What are the emerging trends in competitive intelligence technology, such as machine learning algorithms for predictive analysis or augmented reality interfaces for data visualization, as discussed in technology blogs and whitepapers?

# %% [markdown]
# ask chiarello if he wants the dashboard to be constantly updated or it has static data

# %% [markdown]
# sara hoxha's opinions:
#
# questions 1/2 -> unsure yet
#
# question 3 -> sentiments are very important to deduce overall idea about chatgpt (we can achieve it thru text mining via datacamp approaches) for me its necessary to keep it
#
# question 4 -> maybe discuss if we want to be more specific towards or about gpt as out main tool
#
# question 5 -> i like it, not my favourite but it gives a nice idea of the whole gen ai approach according to experts
#
# question 6 -> again this seems more future outlook, depends if thats a direction we want to focus on
#
# question 7 -> maybe reformulate as before/after gpt, with a focus on how employment approaches, digital nomadism has been impacted
#
# question 8 -> i like it
#
# question 9 -> i like it
#
# question 10 -> it doesnt make the most sense to me, maybe we need to clarify what we mean by subjects (is it the column in the dataset), anyway i wouldnt consider it as one of the most important questions
#
# question 11 -> maybe have a look also of the ethical implications coming from using generative ai for our own work not just competitors, overall i like it
#
# question 12 -> if we dont want to follow a more research paper vibe where we talk also about the future, but we only want to focus on the presence and how it was before chatgpt i would suggest to remove the question 12
